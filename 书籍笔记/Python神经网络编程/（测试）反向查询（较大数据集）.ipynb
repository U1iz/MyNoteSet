# %%
import source as src

# %%
network_info = {
    'node_num': (784, 100, 10),
    'learning_grate': 0.3,
    'train_file': './mnist_dataset/pjreddie/mnist_train.csv',
    'epochs': 1
}

example =  src.train(network_info)
target = range(10)
src.draw(src.back_query(target, example), len(target)/2)
# Out:
# 第1世代 <source.neuralNetwork object at 0x000001CB613651C0>
# 测试

# %%
network_info = {
    'node_num': (784, 128, 10),
    'learning_grate': 0.1,
    'train_file': './mnist_dataset/pjreddie/mnist_train.csv',
    'epochs': 6
}

example =  src.train(network_info)
target = range(10)
src.draw(src.back_query(target, example), len(target)/2)
# Out:
# 第1世代 <source.neuralNetwork object at 0x000001CB49C669A0>
# 第2世代 <source.neuralNetwork object at 0x000001CB49C669A0>
# 第3世代 <source.neuralNetwork object at 0x000001CB49C669A0>
# 第4世代 <source.neuralNetwork object at 0x000001CB49C669A0>
# 第5世代 <source.neuralNetwork object at 0x000001CB49C669A0>
# 第6世代 <source.neuralNetwork object at 0x000001CB49C669A0>
# 测试

# %%
network_info = {
    'node_num': (784, 200, 10),
    'learning_grate': 0.1,
    'train_file': './mnist_dataset/pjreddie/mnist_train.csv',
    'epochs': 7
}

example =  src.train(network_info)
target = range(10)
src.draw(src.back_query(target, example), len(target)/2)
# Out:
# 第1世代 <source.neuralNetwork object at 0x000001CB49FEBB20>
# 第2世代 <source.neuralNetwork object at 0x000001CB49FEBB20>
# 第3世代 <source.neuralNetwork object at 0x000001CB49FEBB20>
# 第4世代 <source.neuralNetwork object at 0x000001CB49FEBB20>
# 第5世代 <source.neuralNetwork object at 0x000001CB49FEBB20>
# 第6世代 <source.neuralNetwork object at 0x000001CB49FEBB20>
# 第7世代 <source.neuralNetwork object at 0x000001CB49FEBB20>
# 测试
