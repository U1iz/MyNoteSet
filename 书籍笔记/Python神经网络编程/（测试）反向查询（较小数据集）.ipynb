# %%
import source as src

# %%
network_info = {
    'node_num': (784, 100, 10),
    'learning_grate': 0.3,
    'train_file': './mnist_dataset/mini/mnist_train_100.csv',
    'epochs': 1
}

example =  src.train(network_info)
target = range(10)
src.draw(src.back_query(target, example), len(target)/2)
# Out:
# 第1世代 <source.neuralNetwork object at 0x00000243D1ACF640>
# 测试

# %%
network_info = {
    'node_num': (784, 100, 10),
    'learning_grate': 0.2,
    'train_file': './mnist_dataset/mini/mnist_train_100.csv',
    'epochs': 6
}

example =  src.train(network_info)
target = range(10)
src.draw(src.back_query(target, example), len(target)/2)
# Out:
# 第1世代 <source.neuralNetwork object at 0x00000243B2A14280>
# 第2世代 <source.neuralNetwork object at 0x00000243B2A14280>
# 第3世代 <source.neuralNetwork object at 0x00000243B2A14280>
# 第4世代 <source.neuralNetwork object at 0x00000243B2A14280>
# 第5世代 <source.neuralNetwork object at 0x00000243B2A14280>
# 第6世代 <source.neuralNetwork object at 0x00000243B2A14280>
# 测试

# %%
network_info = {
    'node_num': (784, 100, 10),
    'learning_grate': 0.1,
    'train_file': './mnist_dataset/mini/mnist_train_100.csv',
    'epochs': 100
}

example =  src.train(network_info)
target = range(10)
src.draw(src.back_query(target, example), len(target)/2)
# Out:
# 第1世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第2世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第3世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第4世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第5世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第6世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第7世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第8世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第9世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第10世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第11世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第12世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第13世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第14世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第15世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第16世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第17世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第18世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第19世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第20世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第21世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第22世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第23世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第24世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第25世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第26世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第27世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第28世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第29世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第30世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第31世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第32世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第33世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第34世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第35世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第36世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第37世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第38世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第39世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第40世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第41世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第42世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第43世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第44世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第45世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第46世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第47世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第48世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第49世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第50世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第51世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第52世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第53世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第54世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第55世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第56世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第57世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第58世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第59世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第60世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第61世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第62世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第63世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第64世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第65世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第66世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第67世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第68世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第69世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第70世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第71世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第72世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第73世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第74世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第75世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第76世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第77世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第78世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第79世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第80世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第81世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第82世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第83世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第84世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第85世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第86世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第87世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第88世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第89世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第90世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第91世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第92世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第93世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第94世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第95世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第96世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第97世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第98世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第99世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 第100世代 <source.neuralNetwork object at 0x00000243B2939C70>
# 测试

# %%
network_info = {
    'node_num': (784, 200, 10),
    'learning_grate': 0.1,
    'train_file': './mnist_dataset/mini/mnist_train_100.csv',
    'epochs': 6
}

example =  src.train(network_info)
target = range(10)
src.draw(src.back_query(target, example), len(target)/2)
# Out:
# 第1世代 <source.neuralNetwork object at 0x000001EC242BECA0>
# 第2世代 <source.neuralNetwork object at 0x000001EC242BECA0>
# 第3世代 <source.neuralNetwork object at 0x000001EC242BECA0>
# 第4世代 <source.neuralNetwork object at 0x000001EC242BECA0>
# 第5世代 <source.neuralNetwork object at 0x000001EC242BECA0>
# 第6世代 <source.neuralNetwork object at 0x000001EC242BECA0>
# 测试
